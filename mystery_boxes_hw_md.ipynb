# %% [markdown]
# <a href="https://colab.research.google.com/github/NagisaSato/Unit-1/blob/main/mystery_boxes_hw_md.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Screen Shot 2021-09-30 at 12.01.44.png](data:image/png;base64,...)

# %%
a = "Hello"
def mystery_box1(a,b):
  if b == "True":
    n = "olleh"
  else:
    if b == "False":
      n = "olleH"
    else: 
      n = "error"
  return n

final = mystery_box1(a, "False")
print(final)
# Out:
# olleH

# %% [markdown]
# ![Screen Shot 2021-09-30 at 12.09.47.png](data:image/png;base64,...)

# %%
def mystery_box2(email):
  name = ''
  mail = ''
  digit = ''

# %% [markdown]
# ![Screen Shot 2021-09-30 at 14.05.55.png](data:image/png;base64,...)

# %%
def lcm(a,b,c):
  if a >= b and a >= c:
    n = a
  else:
    if b >= a and b >= c:
      n = b
    else:
      n = c

  while(True):
    if (n % a == 0) and (n % b == 0) and (n % c == 0):
      lcm = n
      break
    n += 1
  return n

answer = lcm(5,6,3)
print(answer)
# Out:
# 30
